# %%
import pandas as pd

# %% [markdown]
# ## Read From CSV File

# %%
df = pd.read_csv("data/parks.csv")

# %%
df.head()
# Out:
#   Park Code               Park Name State   Acres  Latitude  Longitude
# 0      ACAD    Acadia National Park    ME   47390     44.35     -68.21
# 1      LKAD      NULL National Park   NaN   47390       NaN     -68.21
# 2      ARCH    Arches National Park    UT   76519     38.68    -109.57
# 3      BADL  Badlands National Park    SD  242756     43.75    -102.50
# 4      BIBE  Big Bend National Park    TX  801163     29.25    -103.25

# %% [markdown]
# ## Slicing the Data Frame

# %%
X = df [2:4]

# %%
X
# Out:
#   Park Code               Park Name State   Acres  Latitude  Longitude
# 2      ARCH    Arches National Park    UT   76519     38.68    -109.57
# 3      BADL  Badlands National Park    SD  242756     43.75    -102.50

# %% [markdown]
# ## Indexing Columns

# %%
df['State'].head()
# Out:
# 0     ME
# 1    NaN
# 2     UT
# 3     SD
# 4     TX
# Name: State, dtype: object

# %%
df.State.head()
# Out:
# 0     ME
# 1    NaN
# 2     UT
# 3     SD
# 4     TX
# Name: State, dtype: object

# %% [markdown]
# We can only access the 'Park Code' column by passing its name as a string in brackets, like df['Park Code']. I recommend either always using that approach or always converting your column names into a valid format as soon as you read in the data so that you don't have to mix the two methods. It's just a bit tidier.
#
# It's a good practice to clean your column names to prevent this sort of error. I'll use a very short cleaning function here since the names don't have any odd characters. By convention, the names should also be converted to lower case. Pandas is case sensitive, so future calls to all of the columns will need to be updated.

# %%
df.columns = [col.replace(' ', '_').lower() for col in df.columns]
print(df.columns)
# Out:
# Index(['park_code', 'park_name', 'state', 'acres', 'latitude', 'longitude'], dtype='object')

# %% [markdown]
# ## Indexing Columns & Rows

# %%
df[['state', 'acres']][:3]
# Out:
#   state  acres
# 0    ME  47390
# 1   NaN  47390
# 2    UT  76519

# %% [markdown]
# ## Selecting Subset Of Data

# %%
(df.state == 'UT').head(3)
# Out:
# 0    False
# 1    False
# 2     True
# Name: state, dtype: bool

# %% [markdown]
# We get a series of the results of the boolean. Passing that series into a dataframe gives us the subset of the dataframe where the boolean evaluates to True.

# %%
df[df.state == 'UT']
# Out:
#    park_code                   park_name state   acres  latitude  longitude
# 2       ARCH        Arches National Park    UT   76519     38.68    -109.57
# 7       BRCA  Bryce Canyon National Park    UT   35835     37.57    -112.18
# 8       CANY   Canyonlands National Park    UT  337598     38.20    -109.93
# 9       CARE  Capitol Reef National Park    UT  241904     38.20    -111.17
# 56      ZION          Zion National Park    UT  146598     37.30    -113.05

# %%
df[(df.latitude > 60) | (df.acres > 10**6)].head(3)
# Out:
#    park_code                          park_name   state    acres  latitude  \
# 15      DENA  Denali National Park and Preserve      AK  3372402     63.33
# 16      DEVA         Death Valley National Park  CA, NV  4740912     36.24
# 18      EVER           Everglades National Park      FL  1508538     25.32
#
#     longitude
# 15    -150.50
# 16    -116.82
# 18     -80.93

# %%
df.transpose()
# Out:
#                              0                   1                     2   \
# park_code                  ACAD                LKAD                  ARCH
# park_name  Acadia National Park  NULL National Park  Arches National Park
# state                        ME                 NaN                    UT
# acres                     47390               47390                 76519
# latitude                  44.35                 NaN                 38.68
# longitude                -68.21              -68.21               -109.57
#
#                                3                       4   \
# park_code                    BADL                    BIBE
# park_name  Badlands National Park  Big Bend National Park
# state                          SD                      TX
# acres                      242756                  801163
# latitude                    43.75                   29.25
# longitude                  -102.5                 -103.25
#
#                                5                                           6   \
# park_code                    BISC                                        BLCA
# park_name  Biscayne National Park  Black Canyon of the Gunnison National Park
# state                          FL                                          CO
# acres                      172924                                       32950
# latitude                    25.65                                       38.57
# longitude                  -80.08                                     -107.72
#
#                                    7                          8   \
# park_code                        BRCA                       CANY
# park_name  Bryce Canyon National Park  Canyonlands National Park
# state                              UT                         UT
# acres                           35835                     337598
# latitude                        37.57                       38.2
# longitude                     -112.18                    -109.93
#
#                                    9   ...                     47  \
# park_code                        CARE  ...                   SAGU
# park_name  Capitol Reef National Park  ...  Saguaro National Park
# state                              UT  ...                     AZ
# acres                          241904  ...                  91440
# latitude                         38.2  ...                  32.25
# longitude                     -111.17  ...                 -110.5
#
#                                                 48                        49  \
# park_code                                     SEKI                      SHEN
# park_name  Sequoia and Kings Canyon National Parks  Shenandoah National Park
# state                                           CA                        VA
# acres                                       865952                    199045
# latitude                                     36.43                     38.53
# longitude                                  -118.68                    -78.35
#
#                                          50                       51  \
# park_code                              THRO                     VOYA
# park_name  Theodore Roosevelt National Park  Voyageurs National Park
# state                                    ND                       MN
# acres                                 70447                   218200
# latitude                              46.97                     48.5
# longitude                           -103.45                   -92.88
#
#                                 52  \
# park_code                     WICA
# park_name  Wind Cave National Park
# state                           SD
# acres                        28295
# latitude                     43.57
# longitude                  -103.48
#
#                                                        53  \
# park_code                                            WRST
# park_name  Wrangell - St Elias National Park and Preserve
# state                                                  AK
# acres                                             8323148
# latitude                                               61
# longitude                                            -142
#
#                                   54                      55  \
# park_code                       YELL                    YOSE
# park_name  Yellowstone National Park  Yosemite National Park
# state                     WY, MT, ID                      CA
# acres                        2219791                  761266
# latitude                        44.6                   37.83
# longitude                     -110.5                  -119.5
#
#                            56
# park_code                ZION
# park_name  Zion National Park
# state                      UT
# acres                  146598
# latitude                 37.3
# longitude             -113.05
#
# [6 rows x 57 columns]

# %% [markdown]
# ## Identifiying NULL values in Columns

# %%
df[df.state.isnull()]
# Out:
#   park_code           park_name state  acres  latitude  longitude
# 1      LKAD  NULL National Park   NaN  47390       NaN     -68.21

# %% [markdown]
# ## Dropping Null Values

# %%
df.dropna()
# Out:
#    park_code                                       park_name       state  \
# 0       ACAD                            Acadia National Park          ME
# 2       ARCH                            Arches National Park          UT
# 3       BADL                          Badlands National Park          SD
# 4       BIBE                          Big Bend National Park          TX
# 5       BISC                          Biscayne National Park          FL
# 6       BLCA      Black Canyon of the Gunnison National Park          CO
# 7       BRCA                      Bryce Canyon National Park          UT
# 8       CANY                       Canyonlands National Park          UT
# 9       CARE                      Capitol Reef National Park          UT
# 10      CAVE                  Carlsbad Caverns National Park          NM
# 11      CHIS                   Channel Islands National Park          CA
# 12      CONG                          Congaree National Park          SC
# 13      CRLA                       Crater Lake National Park          OR
# 14      CUVA                   Cuyahoga Valley National Park          OH
# 15      DENA               Denali National Park and Preserve          AK
# 16      DEVA                      Death Valley National Park      CA, NV
# 17      DRTO                      Dry Tortugas National Park          FL
# 18      EVER                        Everglades National Park          FL
# 19      GAAR  Gates Of The Arctic National Park and Preserve          AK
# 20      GLAC                           Glacier National Park          MT
# 21      GLBA          Glacier Bay National Park and Preserve          AK
# 22      GRBA                       Great Basin National Park          NV
# 23      GRCA                      Grand Canyon National Park          AZ
# 24      GRSA     Great Sand Dunes National Park and Preserve          CO
# 25      GRSM             Great Smoky Mountains National Park      TN, NC
# 26      GRTE                       Grand Teton National Park          WY
# 27      GUMO               Guadalupe Mountains National Park          TX
# 28      HALE                         Haleakala National Park          HI
# 29      HAVO                  Hawaii Volcanoes National Park          HI
# 30      HOSP                       Hot Springs National Park          AR
# 31      ISRO                       Isle Royale National Park          MI
# 32      JOTR                       Joshua Tree National Park          CA
# 33      KATM               Katmai National Park and Preserve          AK
# 34      KEFJ                      Kenai Fjords National Park          AK
# 35      KOVA                      Kobuk Valley National Park          AK
# 36      LACL           Lake Clark National Park and Preserve          AK
# 37      LAVO                   Lassen Volcanic National Park          CA
# 38      MACA                      Mammoth Cave National Park          KY
# 39      MEVE                        Mesa Verde National Park          CO
# 40      MORA                     Mount Rainier National Park          WA
# 41      NOCA                    North Cascades National Park          WA
# 42      OLYM                           Olympic National Park          WA
# 43      PEFO                  Petrified Forest National Park          AZ
# 44      PINN                         Pinnacles National Park          CA
# 45      REDW                           Redwood National Park          CA
# 46      ROMO                    Rocky Mountain National Park          CO
# 47      SAGU                           Saguaro National Park          AZ
# 48      SEKI         Sequoia and Kings Canyon National Parks          CA
# 49      SHEN                        Shenandoah National Park          VA
# 50      THRO                Theodore Roosevelt National Park          ND
# 51      VOYA                         Voyageurs National Park          MN
# 52      WICA                         Wind Cave National Park          SD
# 53      WRST  Wrangell - St Elias National Park and Preserve          AK
# 54      YELL                       Yellowstone National Park  WY, MT, ID
# 55      YOSE                          Yosemite National Park          CA
# 56      ZION                              Zion National Park          UT
#
#       acres  latitude  longitude
# 0     47390     44.35     -68.21
# 2     76519     38.68    -109.57
# 3    242756     43.75    -102.50
# 4    801163     29.25    -103.25
# 5    172924     25.65     -80.08
# 6     32950     38.57    -107.72
# 7     35835     37.57    -112.18
# 8    337598     38.20    -109.93
# 9    241904     38.20    -111.17
# 10    46766     32.17    -104.44
# 11   249561     34.01    -119.42
# 12    26546     33.78     -80.78
# 13   183224     42.94    -122.10
# 14    32950     41.24     -81.55
# 15  3372402     63.33    -150.50
# 16  4740912     36.24    -116.82
# 17    64701     24.63     -82.87
# 18  1508538     25.32     -80.93
# 19  7523898     67.78    -153.30
# 20  1013572     48.80    -114.00
# 21  3224840     58.50    -137.00
# 22    77180     38.98    -114.30
# 23  1217403     36.06    -112.14
# 24    42984     37.73    -105.51
# 25   521490     35.68     -83.53
# 26   309995     43.73    -110.80
# 27    86416     31.92    -104.87
# 28    29094     20.72    -156.17
# 29   323431     19.38    -155.20
# 30     5550     34.51     -93.05
# 31   571790     48.10     -88.55
# 32   789745     33.79    -115.90
# 33  3674530     58.50    -155.00
# 34   669983     59.92    -149.65
# 35  1750717     67.55    -159.28
# 36  2619733     60.97    -153.42
# 37   106372     40.49    -121.51
# 38    52830     37.18     -86.10
# 39    52122     37.18    -108.49
# 40   235625     46.85    -121.75
# 41   504781     48.70    -121.20
# 42   922651     47.97    -123.50
# 43    93533     35.07    -109.78
# 44    26606     36.48    -121.16
# 45   112512     41.30    -124.00
# 46   265828     40.40    -105.58
# 47    91440     32.25    -110.50
# 48   865952     36.43    -118.68
# 49   199045     38.53     -78.35
# 50    70447     46.97    -103.45
# 51   218200     48.50     -92.88
# 52    28295     43.57    -103.48
# 53  8323148     61.00    -142.00
# 54  2219791     44.60    -110.50
# 55   761266     37.83    -119.50
# 56   146598     37.30    -113.05
